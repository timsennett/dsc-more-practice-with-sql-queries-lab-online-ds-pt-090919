# %% [markdown]
# # More Practice With SQL Queries - Lab
#
# ## Introduction
#
# In this lesson, we'll run through some practice questions to refresh your knowledge of SQL Queries!
#
# ## Objectives
#
# You will be able to:
#
# - Use `GROUP BY` statements in SQL to apply aggregate functions like: `COUNT`, `MAX`, `MIN`, and `SUM`
# - Decide and perform whichever type of join is best for retrieving desired data
# - Use the `HAVING` clause to compare different aggregates
# - Write subqueries to decompose complex queries
#
# ## Getting Started
#
# As in previous labs, we'll make use of the `sqlite3` library as well as Pandas. By combining them, we'll be able to write queries as Python strings, and make sure that the results are always returned as a Pandas DataFrame.
#
# We'll start by loading both libraries and connecting to the database we'll be using for this lab, `data.sqlite`. You may remember this database from a previous lab. As a refresher, here's the ERD diagram for this database:
#
# <img src='images/Database-Schema.png'>
#
# In the cell below:
#
# * Import the necessary libraries `pandas` and `sqlite3`
# * Establish a connection to the database `data.sqlite`
# * Get the `cursor` from the connection and store it in the variable `c`

# %%
ls
# Out:
# CONTRIBUTING.md  README.md        images/
# LICENSE.md       data.sqlite      index.ipynb

# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect('data.sqlite')
c = conn.cursor()

# %% [markdown]
# ## Basic Queries
#
# Now, let's review basic SQL queries. In the cell below:
#
# Write a query that gets the first name, last name, phone number, address, and credit limit for all customers in California with a credit limit greater than 25000.00.

# %%
# For the first query, the boilerplate for getting 
# the query into a DataFrame has been provided for you

c.execute("""SELECT contactFirstName, contactLastName, phone, addressLine1, addressLine2, city, state, postalCode, country, creditLimit
             FROM customers;""")

df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#     contactFirstName  contactLastName               phone  \
# 0            Carine           Schmitt          40.32.2555
# 1               Jean             King          7025551838
# 2              Peter         Ferguson        03 9520 4555
# 3            Janine           Labrune          40.67.8555
# 4             Jonas        Bergulfsen          07-98 9555
# 5              Susan           Nelson          4155551450
# 6           Zbyszek   Piestrzeniewicz       (26) 642-7555
# 7             Roland           Keitel   +49 69 66 90 2555
# 8              Julie           Murphy          6505555787
# 9               Kwai              Lee          2125557818
# 10            Diego            Freyre      (91) 555 94 44
# 11        Christina          Berglund        0921-12 3555
# 12            Jytte          Petersen          31 12 3555
# 13             Mary           Saveley          78.32.5555
# 14              Eric        Natividad        +65 221 7555
# 15              Jeff            Young          2125557413
# 16            Kelvin            Leong          2155551555
# 17              Juri        Hashimoto          6505556809
# 18             Wendy        Victorino        +65 224 1555
# 19            Veysel           Oeztan       +47 2267 3215
# 20             Keith           Franco          2035557845
# 21           Isabel         de Castro        (1) 356-5555
# 22          Martine             Rancé          20.16.1555
# 23             Marie         Bertrand      (1) 42.34.2555
# 24             Jerry            Tseng          6175555555
# 25             Julie             King          2035552570
# 26              Mory          Kentary    +81 06 6342 5555
# 27           Michael            Frick          2125551500
# 28             Matti        Karttunen         90-224 8555
# 29            Rachel         Ashworth      (171) 555-1555
# ..               ...              ...                 ...
# 92         Maurizio            Moroni         0522-556555
# 93             Akiko        Shimamura     +81 3 3584 0555
# 94         Dominique          Perrier      (1) 47.55.6555
# 95             Rita            Müller         0711-555361
# 96             Sarah            McRoy         04 499 9555
# 97           Michael      Donnermeyer   +49 89 61 08 9555
# 98             Maria        Hernandez          2125558493
# 99        Alexander             Feuer         0342-555176
# 100              Dan            Lewis          2035554407
# 101           Martha          Larsson        0695-34 6555
# 102              Sue            Frick          4085553659
# 103          Roland            Mendel           7675-3555
# 104           Leslie           Murphy          2035559545
# 105               Yu             Choi          2125551957
# 106          Martín            Sommer      (91) 555 22 82
# 107            Sven           Ottlieb         0241-039123
# 108          Violeta          Benitez          5085552555
# 109           Carmen            Anton      +34 913 728555
# 110             Sean         Clenahan      61-9-3844-6555
# 111           Franco          Ricotti       +39 022515555
# 112            Steve         Thompson          3105553722
# 113           Hanna              Moos          0621-08555
# 114       Alexander           Semenov     +7 812 293 0521
# 115           Raanan      Altagar,G M    + 972 9 959 8555
# 116      José Pedro              Roel      (95) 555 82 82
# 117             Rosa          Salazar          2155559857
# 118              Sue           Taylor          4155554312
# 119          Thomas             Smith      (171) 555-7555
# 120          Valarie           Franco          6175552555
# 121             Tony          Snowden       +64 9 5555500
#
#                          addressLine1              addressLine2  \
# 0                      54, rue Royale
# 1                     8489 Strong St.
# 2                   636 St Kilda Road                   Level 3
# 3        67, rue des Cinquante Otages
# 4              Erling Skakkes gate 78
# 5                     5677 Strong St.
# 6                     ul. Filtrowa 68
# 7                       Lyonerstr. 34
# 8           5557 North Pendale Street
# 9             897 Long Airport Avenue
# 10                 C/ Moralzarzal, 86
# 11                    Berguvsvägen  8
# 12                       Vinbæltet 34
# 13                 2, rue du Commerce
# 14                         Bronz Sok.  Bronz Apt. 3/6 Tesvikiye
# 15                  4092 Furth Circle                 Suite 400
# 16                   7586 Pompton St.
# 17                  9408 Furth Circle
# 18            106 Linden Road Sandown                 2nd Floor
# 19                    Brehmen St. 121            PR 334 Sentrum
# 20                  149 Spinnaker Dr.                 Suite 101
# 21             Estrada da saúde n. 58
# 22           184, chaussée de Tournai
# 23            265, boulevard Charonne
# 24                     4658 Baden Av.
# 25                25593 South Bay Ln.
# 26                      1-6-20 Dojima
# 27                  2678 Kingston Rd.                 Suite 101
# 28                      Keskuskatu 45
# 29                  Fauntleroy Circus
# ..                                ...                       ...
# 92             Strada Provinciale 124
# 93                     2-2-8 Roppongi
# 94                  25, rue Lauriston
# 95                  Adenauerallee 900
# 96                   101 Lambton Quay                  Level 11
# 97                       Hansastr. 15
# 98                   5905 Pompton St.                 Suite 750
# 99                        Heerstr. 22
# 100                  2440 Pompton St.
# 101                      Åkergatan 24
# 102                    3086 Ingle Ln.
# 103                      Kirchgasse 6
# 104          567 North Pendale Street
# 105         5290 North Pendale Street                 Suite 200
# 106                    C/ Araquil, 67
# 107                      Walserweg 21
# 108                 1785 First Street
# 109  c/ Gobelas, 19-1 Urb. La Florida
# 110                    7 Allen Street
# 111             20093 Cologno Monzese       Alessandro Volta 16
# 112                 3675 Furth Circle
# 113                    Forsterstr. 57
# 114                   2 Pobedy Square
# 115                    3 Hagalim Blv.
# 116                     C/ Romero, 33
# 117                 11328 Douglas Av.
# 118                 2793 Furth Circle
# 119                   120 Hanover Sq.
# 120                    6251 Ingle Ln.
# 121                Arenales 1938 3'A'
#
#                  city     state postalCode      country  creditLimit
# 0              Nantes                44000       France      21000.0
# 1           Las Vegas        NV      83030          USA      71800.0
# 2           Melbourne  Victoria       3004    Australia     117300.0
# 3              Nantes                44000       France     118200.0
# 4             Stavern                 4110       Norway      81700.0
# 5          San Rafael        CA      97562          USA     210500.0
# 6            Warszawa               01-012       Poland          0.0
# 7           Frankfurt                60528      Germany      59700.0
# 8       San Francisco        CA      94217          USA      64600.0
# 9                 NYC        NY      10022          USA     114900.0
# 10             Madrid                28034        Spain     227600.0
# 11              Luleå             S-958 22       Sweden      53100.0
# 12          Kobenhavn                 1734      Denmark      83400.0
# 13               Lyon                69004       France     123900.0
# 14          Singapore                79903    Singapore     103800.0
# 15                NYC        NY      10022          USA     138500.0
# 16          Allentown        PA      70267          USA     100600.0
# 17         Burlingame        CA      94217          USA      84600.0
# 18          Singapore                69045    Singapore      97900.0
# 19             Bergen               N 5804     Norway        96800.0
# 20          New Haven        CT      97823          USA          0.0
# 21             Lisboa                 1756     Portugal          0.0
# 22              Lille                59000       France      82900.0
# 23              Paris                75012       France      84300.0
# 24          Cambridge        MA      51247          USA      43400.0
# 25        Bridgewater        CT      97562          USA      84300.0
# 26            Kita-ku     Osaka   530-0003        Japan      81200.0
# 27                NYC        NY      10022          USA      76400.0
# 28           Helsinki                21240      Finland      96500.0
# 29         Manchester              EC2 5NT           UK     136800.0
# ..                ...       ...        ...          ...          ...
# 92      Reggio Emilia                42100        Italy     121400.0
# 93          Minato-ku     Tokyo   106-0032        Japan      94400.0
# 94              Paris                75016       France      95000.0
# 95          Stuttgart                70563      Germany          0.0
# 96         Wellington                       New Zealand      86800.0
# 97             Munich                80686      Germany      77000.0
# 98                NYC        NY      10022          USA      67500.0
# 99            Leipzig                 4179      Germany          0.0
# 100          Glendale        CT      97561          USA      49700.0
# 101            Bräcke             S-844 67       Sweden     116400.0
# 102          San Jose        CA      94217          USA      77600.0
# 103              Graz                 8010      Austria      45300.0
# 104         New Haven        CT      97823          USA      95400.0
# 105               NYC        NY      10022          USA      39800.0
# 106            Madrid                28023        Spain     104600.0
# 107            Aachen                52066      Germany          0.0
# 108       New Bedford        MA      50553          USA      85800.0
# 109            Madrid                28023        Spain          0.0
# 110      Glen Waverly  Victoria       3150    Australia      60300.0
# 111             Milan                             Italy      34800.0
# 112           Burbank        CA      94019          USA      55400.0
# 113          Mannheim                68306      Germany          0.0
# 114  Saint Petersburg               196143       Russia          0.0
# 115           Herzlia                47625       Israel          0.0
# 116           Sevilla                41101        Spain      65700.0
# 117      Philadelphia        PA      71270          USA      72600.0
# 118          Brisbane        CA      94217          USA      60300.0
# 119            London              WA1 1DP           UK      43300.0
# 120            Boston        MA      51003          USA      85100.0
# 121        Auckland                         New Zealand     110000.0
#
# [122 rows x 10 columns]

# %% [markdown]
# #### Expected Output
#
# <img src='images/expected-output-1.png'>
#
# ## Aggregate Functions and GROUP BY
#
# Next, write a query that gets the average credit limit per state.

# %%
c.execute('''SELECT state, AVG(creditLIMIT)
             FROM customers
             WHERE country == "USA"
             GROUP BY state;''')
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#   state  AVG(creditLIMIT)
# 0    CA      83854.545455
# 1    CT      57350.000000
# 2    MA      70755.555556
# 3    NH     114200.000000
# 4    NJ      43000.000000
# 5    NV      71800.000000
# 6    NY      89966.666667
# 7    PA      84766.666667

# %% [markdown]
# #### Expected Output
#
# <img src='images/expected-output-2.png'>
#
# ## JOINs
#
# Now, write a query that uses JOIN statements to get the customer name, customer number, order number, status, and quantity ordered. Print only the head of this DataFrame.

# %%
c.execute('''SELECT customerName, customerNumber, orderNumber, status, quantityOrdered
             FROM customers
             JOIN orders
             USING(customerNumber)
             JOIN orderdetails
             USING(orderNumber);''')

df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df.head()
# Out:
#                    customerName  customerNumber orderNumber   status  \
# 0  Online Diecast Creations Co.             363       10100  Shipped
# 1  Online Diecast Creations Co.             363       10100  Shipped
# 2  Online Diecast Creations Co.             363       10100  Shipped
# 3  Online Diecast Creations Co.             363       10100  Shipped
# 4          Blauer See Auto, Co.             128       10101  Shipped
#
#   quantityOrdered
# 0              22
# 1              30
# 2              49
# 3              50
# 4              25

# %% [markdown]
# #### Expected Output
#
# <img src='images/joins.png'>
#
# ## HAVING and ORDER BY
#
# Now, return the customerName, customerNumber, productName, productCode, and total number ordered for any product a customer has bought 10 or more of cumulatively. Sort the rows in descending order by the quantity ordered.
#
# **_Hint_**: For this one, you'll need to make use of HAVING, GROUP BY, and ORDER BY -- make sure you get the order of them correct!

# %%
c.execute('''SELECT customerName, customerNumber, productName, productCode, SUM(quantityOrdered) as TotalOrdered
             FROM customers
             JOIN orders
             USING(customerNumber)
             JOIN orderdetails
             USING(orderNumber)
             JOIN products
             USING(productCode)
             GROUP BY customerNumber, productCode
             HAVING SUM(quantityOrdered)>=10
             ORDER BY TotalOrdered DESC;''')

df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df.head()
# Out:
#              customerName  customerNumber  \
# 0  Euro+ Shopping Channel             141
# 1  Euro+ Shopping Channel             141
# 2  Euro+ Shopping Channel             141
# 3  Euro+ Shopping Channel             141
# 4  Euro+ Shopping Channel             141
#
#                            productName productCode  TotalOrdered
# 0          1992 Ferrari 360 Spider red    S18_3232           308
# 1  1958 Chevy Corvette Limited Edition    S24_2840           245
# 2                   1970 Dodge Coronet    S24_1444           197
# 3                    1957 Chevy Pickup    S12_4473           183
# 4                  2002 Chevy Corvette    S24_3432           174

# %% [markdown]
# #### Expected Output
#
# <img src='images/having_order.png'>
#
# ## Subqueries
#
# Finally, get the first name, last name, employee number, and office code for employees from offices with less than 5 employees. Print the first five rows of this DataFrame.

# %%
c.execute('''SELECT firstName, lastName, employeeNumber, officeCode
             FROM employees
             WHERE officeCode IN (SELECT officeCode
                                  FROM offices
                                  JOIN employees
                                  USING(officeCode)
                                  GROUP BY 1
                                  HAVING COUNT(employeeNumber)<5);''')

df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df.head()

# Use HAVING instead of WHERE when dealing with aggregates
# Why Group By 1? Ask Ahbineet. A Group by is required before using Having. But why 1?
# Out:
#   firstName   lastName employeeNumber officeCode
# 0   William  Patterson           1088          6
# 1     Julie   Firrelli           1188          2
# 2     Steve  Patterson           1216          2
# 3  Foon Yue      Tseng           1286          3
# 4    George     Vanauf           1323          3

# %% [markdown]
# #### Expected Output
#
# <img src='images/expected-output-5.png'>
#
# # Summary
#
# In this lesson, we reviewed all the major concepts and keywords associated with SQL queries!
